# %%
import pandas as pd
data = pd.read_csv("FTIR Tappert data for import.csv")
data
# Out:
#              Family                Species         Exudate type  \
# 0          Pinaceae         Abies balsamea                resin
# 1               NaN         Abies concolor                resin
# 2               NaN          Abies grandis  volatile-rich resin
# 3               NaN       Abies lasiocarpa                resin
# 4               NaN       Abies lasiocarpa  volatile-rich resin
# ..              ...                    ...                  ...
# 94      Ginkgoaceae          Ginkgo biloba                  gum
# 95        Zamiaceae         Dioon purpusii                  gum
# 96              NaN       Dioon spinulosum                  gum
# 97       Cycadaceae       Cycas circinalis                  gum
# 98  Welwitschiaceae  Welwitschia mirabilis                  gum
#
#                       Locality    650    652    654    656    658    660  ...  \
# 0            Edmonton, Alberta  0.147  0.151  0.153  0.153  0.153  0.152  ...
# ...
